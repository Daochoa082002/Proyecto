# %% [markdown]
# # Segunda Entrega Proyecto

# %% [markdown]
# ## Importar librerias.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt
import altair as alt
from vega_datasets import data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4924/2658197725.py in <module>
#       4 import matplotlib as plt
#       5 import matplotlib.pyplot as plt
# ----> 6 import altair as alt
#       7 from vega_datasets import data
#
# ModuleNotFoundError: No module named 'altair'

# %%
pd.set_option('display.max_columns', None) #Mostrar todas las columnas
sns.set(rc={'figure.figsize':(12.7,8.6)})

# %% [markdown]
# ## Importar Datos

# %% [markdown]
# Datos extraidos de los datos recogidos por el Banco Mundial.
# Url = Fuente: https://datos.bancomundial.org/tema/desarrollo-social?view=chart

# %%
df_proyecto2 = pd.read_csv("C:/Users/fabia/Downloads/Datos_proyectodefinitivo2.csv", 
                 sep = ',',
                )

# %%
df_proyecto2.head()
# Out:
#    Unnamed: 0 Country Name Country Code_x              Indicator Name  \
# 0           0        Aruba            ABW  Esperanza de vida al nacer
# 1           1        Aruba            ABW  Esperanza de vida al nacer
# 2           2        Aruba            ABW          Tasa de fertilidad
# 3           3        Aruba            ABW         Refugiados por pais
# 4           4        Aruba            ABW         Refugiados por pais
#
#                        Region  Income_Group Sexo_o_clase          Edad  \
# 0  America Latina y el Caribe  Ingreso alto       Hombre         Total
# 1  America Latina y el Caribe  Ingreso alto        Mujer         Total
# 2  America Latina y el Caribe  Ingreso alto        Mujer  15 a 19 años
# 3  America Latina y el Caribe  Ingreso alto    de Origen         Total
# 4  America Latina y el Caribe  Ingreso alto     de Asilo         Total
#
#      2000    2001    2002     2003     2004     2005     2006    2007    2008  \
# 0  71.312  71.382  71.469  71.5720  71.6880  71.8160  71.9520  72.093  72.235
# 1  76.257  76.307  76.375  76.4650  76.5750  76.7030  76.8450  76.992  77.140
# 2  43.593  42.356  41.119  39.6676  38.2162  36.7648  35.3134  33.862  32.792
# 3     NaN     NaN     NaN      NaN      NaN      NaN      NaN     NaN     NaN
# 4     NaN     NaN     NaN      NaN      NaN      NaN      NaN     NaN     NaN
#
#      2009    2010    2011    2012     2013     2014     2015     2016    2017  \
# 0  72.377  72.517  72.654  72.792  72.9300  73.0690  73.2080  73.3480  73.488
# 1  77.285  77.425  77.561  77.695  77.8300  77.9650  78.1010  78.2370  78.372
# 2  31.722  30.652  29.582  28.512  27.3444  26.1768  25.0092  23.8416  22.674
# 3     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN     NaN
# 4     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN     NaN
#
#       2018     2019  2020
# 0  73.6280  73.7680   NaN
# 1  78.5070  78.6410   NaN
# 2  21.1736  19.6732   NaN
# 3      NaN      NaN   NaN
# 4      NaN      NaN   NaN

# %% [markdown]
# ## Pre-procesamiento de los datos.

# %%
df_proyecto_2 = pd.pivot_table(df_proyecto2, 
                                values=['2000',"2001","2002","2003","2004","2005","2006","2007","2008","2009",
                                       "2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020"], 
                                index=["Indicator Name"],
                                    columns=['Country Name',"Sexo_o_clase","Income_Group","Region"], 
                                aggfunc=np.mean)
df_proyecto_2 = pd.DataFrame(df_proyecto_2)

# %%
df_proyecto_2 = df_proyecto_2.transpose().reset_index()

# %%
df_proyecto_2.head()
# Out:
# Indicator Name level_0 Country Name    Sexo_o_clase            Income_Group  \
# 0                 2000   Afganistán          Hombre  Países de ingreso bajo
# 1                 2000   Afganistán  Hombre y Mujer  Países de ingreso bajo
# 2                 2000   Afganistán           Mujer  Países de ingreso bajo
# 3                 2000   Afganistán        Primaria  Países de ingreso bajo
# 4                 2000   Afganistán       de Origen  Países de ingreso bajo
#
# Indicator Name           Region  Desempleo  Esperanza de vida al nacer  \
# 0               Asia meridional     10.254                      54.663
# 1               Asia meridional        NaN                         NaN
# 2               Asia meridional     13.846                      57.120
# 3               Asia meridional        NaN                         NaN
# 4               Asia meridional        NaN                         NaN
#
# Indicator Name  Porcentaje de Prevalencia de VIH  \
# 0                                            0.1
# 1                                            NaN
# 2                                            0.1
# 3                                            NaN
# 4                                            NaN
#
# Indicator Name  Porcentaje de empleo vulnerable  \
# 0                                     91.879999
# 1                                           NaN
# 2                                     98.720002
# 3                                           NaN
# 4                                           NaN
#
# Indicator Name  Porcentaje de niños economicamente activos  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#
# Indicator Name  Porcentaje de niños que solo trabajan  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
#
# Indicator Name  Porcentaje de niños que solo trabajan y estudian  \
# 0                                                            NaN
# 1                                                            NaN
# 2                                                            NaN
# 3                                                            NaN
# 4                                                            NaN
#
# Indicator Name  Razon de educacion de mujeres frente a hombres  \
# 0                                                          NaN
# 1                                                          NaN
# 2                                                          NaN
# 3                                                          0.0
# 4                                                          NaN
#
# Indicator Name  Razon de ocupacion en paralamentos nacionales  \
# 0                                                         NaN
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
#
# Indicator Name  Refugiados por pais  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                         3587327.0
#
# Indicator Name  Tasa de Participacion en la fuerza laboral  \
# 0                                                70.871500
# 1                                                43.694001
# 2                                                14.230500
# 3                                                      NaN
# 4                                                      NaN
#
# Indicator Name  Tasa de Poblacion Activa  Tasa de fertilidad
# 0                              76.646004                 NaN
# 1                                    NaN                 NaN
# 2                              14.795000             153.951
# 3                                    NaN                 NaN
# 4                                    NaN                 NaN

# %%
df_proyecto_2 = df_proyecto_2.rename(columns = {"level_0" : "Año"})

# %%
df_proyecto_2['Año'] = pd.to_datetime(df_proyecto_2['Año'],format='%Y')

# %%
df_proyecto_2['Año'].value_counts()
# Out:
# 2011-01-01    1562
# 2012-01-01    1541
# 2014-01-01    1540
# 2015-01-01    1536
# 2010-01-01    1532
# 2018-01-01    1523
# 2007-01-01    1518
# 2009-01-01    1518
# 2008-01-01    1516
# 2005-01-01    1511
# 2016-01-01    1507
# 2004-01-01    1504
# 2006-01-01    1498
# 2000-01-01    1495
# 2017-01-01    1494
# 2013-01-01    1488
# 2002-01-01    1487
# 2001-01-01    1471
# 2003-01-01    1460
# 2019-01-01    1433
# 2020-01-01    1176
# Name: Año, dtype: int64

# %% [markdown]
# ## Grafico de lineas (Juan Bohorquez)

# %%
df_desempleo = pd.pivot_table(df_proyecto_2, 
                                values=["Desempleo"], 
                                index=["Sexo_o_clase"],
                                    columns=["Año","Income_Group"], 
                                aggfunc=np.mean)
df_desempleo = pd.DataFrame(df_desempleo)

# %%
df_desempleo.reset_index().head()
# Out:
# Indicator Name Sexo_o_clase    Desempleo                                      \
# Año                     NaT   2000-01-01
# Income_Group                Ingreso alto Ingreso mediano alto No clasificado
# 0                    Hombre     7.252446            10.674020         13.615
# 1                     Mujer     8.728089            13.441163         14.604
#
# Indicator Name                                                        \
# Año
# Income_Group   Países de ingreso bajo Países de ingreso mediano bajo
# 0                            5.533148                       7.842943
# 1                            6.817815                       9.458585
#
# Indicator Name                                                   \
# Año              2001-01-01
# Income_Group   Ingreso alto Ingreso mediano alto No clasificado
# 0                  7.079982            10.763000         12.380
# 1                  8.491375            13.295347         14.111
#
# Indicator Name                                                        \
# Año
# Income_Group   Países de ingreso bajo Países de ingreso mediano bajo
# 0                            5.563037                       7.890038
# 1                            7.110037                       9.625113
#
# Indicator Name                                                   \
# Año              2002-01-01
# Income_Group   Ingreso alto Ingreso mediano alto No clasificado
# 0                  7.247036            10.999326         14.512
# 1                  8.655536            13.547123         18.927
#
# Indicator Name                                                        \
# Año
# Income_Group   Países de ingreso bajo Países de ingreso mediano bajo
# 0                            5.579889                       8.075094
# 1                            7.191370                       9.793321
#
# Indicator Name                                                   \
# Año              2003-01-01
# Income_Group   Ingreso alto Ingreso mediano alto No clasificado
# 0                  7.367482            10.777327      14.576000
# 1                  8.894804            13.439122      20.523001
#
# Indicator Name                                                        \
# Año
# Income_Group   Países de ingreso bajo Países de ingreso mediano bajo
# 0                            5.553259                       7.845566
# 1                            7.219444                       9.736132
#
# Indicator Name                                                   \
# Año              2004-01-01
# Income_Group   Ingreso alto Ingreso mediano alto No clasificado
# 0                  7.120607            10.518592      13.291000
# 1                  8.749464            13.361143      17.955999
#
# Indicator Name                                                        \
# Año
# Income_Group   Países de ingreso bajo Países de ingreso mediano bajo
# 0                            5.483926                       7.600226
# 1                            7.258704                       9.575641
#
# Indicator Name                                                   \
# Año              2005-01-01
# Income_Group   Ingreso alto Ingreso mediano alto No clasificado
# 0                  6.717018            10.188531         10.040
# 1                  8.518357            13.201306         11.639
#
# Indicator Name                                                        \
# Año
# Income_Group   Países de ingreso bajo Países de ingreso mediano bajo
# 0                            5.460148                       7.452359
# 1                            7.320519                       9.587623
#
# Indicator Name                                                   \
# Año              2006-01-01
# Income_Group   Ingreso alto Ingreso mediano alto No clasificado
# 0                  6.053643             9.771653          8.112
# 1                  7.871643            12.602755          9.393
#
# Indicator Name                                                        \
# Año
# Income_Group   Países de ingreso bajo Países de ingreso mediano bajo
# 0                            5.464815                       7.198887
# 1                            7.439000                       9.193906
#
# Indicator Name                                                   \
# Año              2007-01-01
# Income_Group   Ingreso alto Ingreso mediano alto No clasificado
# 0                  5.484268             9.178714          7.046
# 1                  7.208161            11.917531          7.646
#
# Indicator Name                                                        \
# Año
# Income_Group   Países de ingreso bajo Países de ingreso mediano bajo
# 0                            5.491037                       7.055774
# 1                            7.597074                       9.058151
#
# Indicator Name                                                   \
# Año              2008-01-01
# Income_Group   Ingreso alto Ingreso mediano alto No clasificado
# 0                  5.572571             8.874510          6.266
# 1                  7.029339            11.452122          6.226
#
# Indicator Name                                                        \
# Año
# Income_Group   Países de ingreso bajo Países de ingreso mediano bajo
# 0                            5.532630                       6.942906
# 1                            7.558148                       9.019094
#
# Indicator Name                                                   \
# Año              2009-01-01
# Income_Group   Ingreso alto Ingreso mediano alto No clasificado
# 0                  7.997464             9.612653          6.187
# 1                  8.423179            12.098306          5.967
#
# Indicator Name                                                        \
# Año
# Income_Group   Países de ingreso bajo Países de ingreso mediano bajo
# 0                            5.249444                       7.040509
# 1                            7.681444                       9.284849
#
# Indicator Name                                                   \
# Año              2010-01-01
# Income_Group   Ingreso alto Ingreso mediano alto No clasificado
# 0                  8.431821             9.772796          7.216
# 1                  8.866911            12.250939          6.946
#
# Indicator Name                                                        \
# Año
# Income_Group   Países de ingreso bajo Países de ingreso mediano bajo
# 0                            5.264296                        7.01666
# 1                            7.867926                        9.43900
#
# Indicator Name                                                   \
# Año              2011-01-01
# Income_Group   Ingreso alto Ingreso mediano alto No clasificado
# 0                  8.185143             9.829531          6.699
# 1                  9.067536            12.135306          7.209
#
# Indicator Name                                                        \
# Año
# Income_Group   Países de ingreso bajo Países de ingreso mediano bajo
# 0                            5.225000                       6.887792
# 1                            7.874519                       9.402453
#
# Indicator Name                                                   \
# Año              2012-01-01
# Income_Group   Ingreso alto Ingreso mediano alto No clasificado
# 0                  8.471589             9.759020          6.267
# 1                  9.345125            11.977347          7.106
#
# Indicator Name                                                        \
# Año
# Income_Group   Países de ingreso bajo Países de ingreso mediano bajo
# 0                            5.232889                       6.810868
# 1                            7.940444                       9.239566
#
# Indicator Name                                                   \
# Año              2013-01-01
# Income_Group   Ingreso alto Ingreso mediano alto No clasificado
# 0                  8.584125             9.857551          6.828
# 1                  9.461000            12.070980          8.598
#
# Indicator Name                                                        \
# Año
# Income_Group   Países de ingreso bajo Países de ingreso mediano bajo
# 0                            5.178926                       6.730793
# 1                            7.854185                       9.230774
#
# Indicator Name                                                   \
# Año              2014-01-01
# Income_Group   Ingreso alto Ingreso mediano alto No clasificado
# 0                  8.106018             9.630653          6.366
# 1                  9.080750            12.038898          7.609
#
# Indicator Name                                                        \
# Año
# Income_Group   Países de ingreso bajo Países de ingreso mediano bajo
# 0                            5.262889                       6.769000
# 1                            7.786000                       9.174245
#
# Indicator Name                                                   \
# Año              2015-01-01
# Income_Group   Ingreso alto Ingreso mediano alto No clasificado
# 0                  7.542125             9.665816          5.800
# 1                  8.589196            12.008551          6.502
#
# Indicator Name                                                        \
# Año
# Income_Group   Países de ingreso bajo Países de ingreso mediano bajo
# 0                            5.324370                       6.796226
# 1                            7.922963                       9.367510
#
# Indicator Name                                                   \
# Año              2016-01-01
# Income_Group   Ingreso alto Ingreso mediano alto No clasificado
# 0                  7.017679             9.685959           5.26
# 1                  8.141732            11.950245           5.41
#
# Indicator Name                                                        \
# Año
# Income_Group   Países de ingreso bajo Países de ingreso mediano bajo
# 0                            5.403259                       6.813264
# 1                            7.938556                       9.434698
#
# Indicator Name                                                   \
# Año              2017-01-01
# Income_Group   Ingreso alto Ingreso mediano alto No clasificado
# 0                  6.404607             9.339041          4.524
# 1                  7.546536            11.749816          5.871
#
# Indicator Name                                                        \
# Año
# Income_Group   Países de ingreso bajo Países de ingreso mediano bajo
# 0                            5.432704                       6.811075
# 1                            7.933852                       9.408623
#
# Indicator Name                                                   \
# Año              2018-01-01
# Income_Group   Ingreso alto Ingreso mediano alto No clasificado
# 0                  5.794714             9.182878          4.505
# 1                  6.947839            11.434735          5.866
#
# Indicator Name                                                        \
# Año
# Income_Group   Países de ingreso bajo Países de ingreso mediano bajo
# 0                            5.432185                       6.845642
# 1                            7.905667                       9.285792
#
# Indicator Name                                                   \
# Año              2019-01-01
# Income_Group   Ingreso alto Ingreso mediano alto No clasificado
# 0                  5.487768             8.943122          4.605
# 1                  6.545964            11.366755          5.998
#
# Indicator Name                                                        \
# Año
# Income_Group   Países de ingreso bajo Países de ingreso mediano bajo
# 0                            5.435852                       6.746887
# 1                            7.898519                       9.240774
#
# Indicator Name                                                   \
# Año              2020-01-01
# Income_Group   Ingreso alto Ingreso mediano alto No clasificado
# 0                  6.629839            10.474694          6.071
# 1                  7.662893            13.020102          7.656
#
# Indicator Name
# Año
# Income_Group   Países de ingreso bajo Países de ingreso mediano bajo
# 0                            6.172519                       7.873019
# 1                            8.866593                      10.504472

# %%
df_desempleo = df_desempleo.transpose().reset_index()

# %%
df_desempleo.head()
# Out:
# Sexo_o_clase Indicator Name        Año                    Income_Group  \
# 0                 Desempleo 2000-01-01                    Ingreso alto
# 1                 Desempleo 2000-01-01            Ingreso mediano alto
# 2                 Desempleo 2000-01-01                  No clasificado
# 3                 Desempleo 2000-01-01          Países de ingreso bajo
# 4                 Desempleo 2000-01-01  Países de ingreso mediano bajo
#
# Sexo_o_clase     Hombre      Mujer
# 0              7.252446   8.728089
# 1             10.674020  13.441163
# 2             13.615000  14.604000
# 3              5.533148   6.817815
# 4              7.842943   9.458585

# %%
df_desempleo = df_desempleo.rename(columns = {"Income_Group" : "Clasificacion de paises por ingreso"})

# %%
df_desempleo = df_desempleo[df_desempleo["Clasificacion de paises por ingreso"] != "No clasficado"]

# %%
import matplotlib.ticker as mtick

sns.lineplot(data=df_desempleo, x="Año", y = "Hombre",hue = "Clasificacion de paises por ingreso")
plt.ticklabel_format(style='plain', axis='y')
ax = plt.gca()
ax.yaxis.set_major_formatter('{x:1.0f}%')
plt.title('Porcentaje de Desempleo hombres segun clasificacion de paises por ingreso',size =20)
plt.ylabel('',size=1)
plt.show()

# %% [markdown]
# ### Tareas
#     Datos:
#         Se usa tabla para clasificar los datos, y se une mediante lineas.
#     Tareas:
#         Comparar tendencias y similitudes con muchos en este caso la clasificacion.
#         Localizar datos atipicos.
#     Representacion visual:
#         linea, posicion vertical, tono de color.

# %% [markdown]
# ### Insights
# Lo curioso de esta visualizacion, la tasa de desempleo para paises de ingreso bajo, ingreso mediano bajo son bajas respecto a los de mayor ingreso y no presentan cambios variados. Otro dato fue el del año 2020 en el que en todos los paises subio debido a la propagacion del Virus Covid-19.

# %% [markdown]
# # Grafico de area radial (Pedro Ochoa)

# %% [markdown]
# Los siguientes codigos es para visualizar los datos de cada pais que vamos a usar.

# %%
df_col = df_proyecto2[df_proyecto2["Indicator Name"] == "Tasa de fertilidad"]

# %%
df_col = df_col[df_col["Country Name"] == "Colombia"]

# %%
df_mex = df_proyecto2[df_proyecto2["Indicator Name"] == "Tasa de fertilidad"]

# %%
df_mex = df_mex[df_mex["Country Name"] == "México"]

# %%
df_ecu = df_proyecto2[df_proyecto2["Indicator Name"] == "Tasa de fertilidad"]

# %%
df_ecu = df_ecu[df_ecu["Country Name"] == "Ecuador"]

# %%
df_ven = df_proyecto2[df_proyecto2["Indicator Name"] == "Tasa de fertilidad"]

# %%
df_ven = df_ven[df_ven["Country Name"] == "Venezuela"]

# %%
from math import pi
# Datos
df_fertilidad = pd.DataFrame({
'group': ['Colombia','Mexico','Ecuador','Venezuela'],
'2008': [80.3788, 69.43, 83.4192, 89.4832],
'2009': [78.6136, 68.565, 83.2504, 89.0674],
'2010': [76.8484, 67.7, 83.0816, 88.6516],
'2011': [75.0832, 66.835, 82.9128, 88.2358],
'2012': [73.318, 65.97, 82.744, 87.82],
'2013': [71.9846, 64.849, 82.0474, 87.3234],
'2014': [70.6512, 63.728, 81.3508, 86.8268],
'2015': [69.3178, 62.607, 80.6542, 86.3302],
'2016': [67.9844, 61.486, 79.9576, 85.8336],
'2017': [66.651, 60.365, 79.261, 85.337],
'2018': [65.482, 59.4542, 78.7626, 84.9792],
'2019': [64.313, 58.5434, 78.2642, 84.6214], 
})
df_fertilidad
# Out:
#        group     2008     2009     2010     2011    2012     2013     2014  \
# 0   Colombia  80.3788  78.6136  76.8484  75.0832  73.318  71.9846  70.6512
# 1     Mexico  69.4300  68.5650  67.7000  66.8350  65.970  64.8490  63.7280
# 2    Ecuador  83.4192  83.2504  83.0816  82.9128  82.744  82.0474  81.3508
# 3  Venezuela  89.4832  89.0674  88.6516  88.2358  87.820  87.3234  86.8268
#
#       2015     2016    2017     2018     2019
# 0  69.3178  67.9844  66.651  65.4820  64.3130
# 1  62.6070  61.4860  60.365  59.4542  58.5434
# 2  80.6542  79.9576  79.261  78.7626  78.2642
# 3  86.3302  85.8336  85.337  84.9792  84.6214

# %%
# ------- PARTE 1: Crear el backgroud
 
# Número de variables numéricas
categories=list(df_fertilidad)[1:]
N = len(categories)
print(categories)
print(N)
# Out:
# ['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']
# 12

# %%
maxnum = df_fertilidad[categories].values.max()
maxnum
# Out:
# 89.4832

# %%
# ¿Cuál será el ángulo de cada eje en el gráfico? (dividimos la parcela / número de variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Iniciar el gráfico de area radial (alias spider plot)
ax = plt.subplot(111, polar=True)
 
# Si tu quieres que el primer eje quede en el top
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)

# Dibujar un por uno el eje y agregar labels
plt.xticks(angles[:-1], categories)
 
# Dibujar los labels de y (ojo con el min y max)
ax.set_rlabel_position(0)
plt.ylim(55,maxnum)

# ------- PARTE 2: Agregar gráficos (uno por uno :( )
 
# Pais de Colombia
values=df_fertilidad.loc[0].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="Colombia")
ax.fill(angles, values, 'blue', alpha=0.1)
 
# Pais de Mexico
values=df_fertilidad.loc[1].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="Mexico")
ax.fill(angles, values, 'blue', alpha=0.1)

# Pais de Ecuador
values=df_fertilidad.loc[2].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="Ecuador")
ax.fill(angles, values, 'blue', alpha=0.1)
 
# Pais de Venezuela
values=df_fertilidad.loc[3].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="Venezuela")
ax.fill(angles, values, 'blue', alpha=0.1)
 
# Agregar leyenda
plt.title('Tasa de fertilidad en adolescentes mujeres entre los 15 a 19 años en porcentajes',size =20)
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# TARAAAAN
plt.show()

# %% [markdown]
# ### Tareas
#     Datos: Tabla donde usa paises y años, una linea de tiempo.
#     Tareas:
#         Comparar tendencias (por años).
#         Localizar valores atipicos.
#     Representacion visual:
#         linea, posicion radial, tono de color.

# %%
df_ecuador = df_proyecto2[df_proyecto2["Country Name"] == "Ecuador"]

# %% [markdown]
# ### Insights
# Lo curioso que se puede detallar de este grafico el cambio inversamente que han tenido Colombia y Mexico respecto a esta tasa. En cambio Venezuela y ECuador que segun la organizacion UNICEF son uno de los paises con mayor tasa en latinoamerica y el Caribe. Lo que trae consecuencias como: "El embarazo en la adolescencia y la maternidad temprana no solo impactan sobre las trayectorias educativas,
# laborales y de salud de niñas y adolescentes madres, sino que también perjudican el desarrollo y el crecimiento
# económico del país. Esto es porque frente a una Tasa Específica de Fecundidad Adolescente (TEFA) alta, es decir,
# frente a una alta proporción de mujeres que fueron madres entre los 10 y 19 años, se ve comprometido el potencial
# que ofrece la fase del bono demográfico. Este fenómeno ocurre cuando la población en edad de trabajar supera en
# cantidad a la población económicamente dependiente (niños y adultos mayores)." En pocas palabras la poblacion que depende economicamente de terceros es alta, la demanda aumenta hacia a ellos frente a una poblacion que no dependa, superando el costo de de adquisicion para la poblacion no dependiente.
